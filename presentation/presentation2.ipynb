# %% [markdown]
# ## Before 2007/6 -> after ==> Are individuals collaborating more or lesser?
# ## topic modelling with different number of topics
# ## include external individuals who are connected to connected to two or more individuals in the school
# ### What are the different clusters that we can find:
# 1. ground-truth
# 2. topic space
# 3.

# %% [markdown]
# # Recap: Hypothesis
# <br>
# <p><span style='font-size:35px'>
# Given a document network:<br>
# topic network should contains correlated topics that mimics the structure of the collaboration network
# <br>
# e.g. number of communities, proportion of communities
# </p>

# %% [markdown]
# ## Pipeline
# <img src='./pipeline.svg'>

# %% [markdown]
# # Data Mining

# %% [markdown]
# Total number of individuals = 296

# %% [markdown]
# <h1> People of Informatics</h1>
# <table style="font-size:24px;">
# <tr>
#     <th> Institute
#     <th> Count
# </tr>
# <tr>
# <td>deanery of clinical sciences</td>
# <td>1</td>
# </tr>
# <tr>
# <td>edinburgh neuroscience </td>
# <td>1</td>
# </tr>
# <tr>
# <td>neuroinformatics dtc</td>
# <td>16</td>
# </tr>
# <tr>
# <td>centre for intelligent systems and their applications</td>
# <td>23 </td>
# </tr>
# <tr>
# <td>institute for adaptive and neural computation</td>
# <td>30</td>
# </tr>
# <tr>
# <td>institute for computing systems architecture</td>
# <td>28</td>
# </tr>
# <tr>
# <td>institute of language cognition and computation</td>
# <td>63</td>
# </tr>
# <tr>
# <td>institute of perception action and behaviour</td>
# <td>20</td>
# </tr>
# <tr>
# <td>laboratory for foundations of computer science</td>
# <td>63</td>
# </tr>
#
# <tr>
# <td>school of philosophy psychology and language sciences</td>
# <td> 1</td>
# </tr>
# <tr>
# <td>UNKNOWN</td>
# <td>50</td>>
# </tr>
# </table>

# %% [markdown]
# <h1>Publications</h1>
# Total count: 8810

# %%
# Summary = title + abstract + publications
pub_concise.head(10)
# Out:
#                                       year  \
# pub_id
# 400818dc-63af-4a26-80c5-906f98e1f8ab  1989
# 18b1a861-afef-4fff-bc80-d02e05be18c4  2013
# 309fdbfc-227b-4588-9264-f0f4e3cadfcb  1994
# d5814bab-5fc2-4c31-92b7-543c7ce75cb4  2012
# 880944d3-26db-4003-9186-130bf3202941  2014
# 57881982-3f10-4035-9dfb-9e76dcfbc00d  2007
# 2fdf828d-62a7-48f0-bd3e-403e20735174  2010
# 46253c7e-fc72-49a0-b7b2-c375d71969ee  2013
# 6b3f3c93-53e1-42b2-be11-66a7cede3a57  2016
# 4481a8b4-22ed-42f5-801a-c0cf515e70d0  1991
#
#                                                                                   title  \
# pub_id
# 400818dc-63af-4a26-80c5-906f98e1f8ab  ballooning stability analysis of jet hmode dis...
# 18b1a861-afef-4fff-bc80-d02e05be18c4               query processing in data integration
# 309fdbfc-227b-4588-9264-f0f4e3cadfcb                               comprehension syntax
# d5814bab-5fc2-4c31-92b7-543c7ce75cb4  evaluation of speaker verification security an...
# ...

# %% [markdown]
# ## Pipeline
# <img src='./pipeline.svg'>

# %% [markdown]
# # Collaboration Network

# %%
## The informatics collaboration network
plt.show()

# %%
print(nx.info(main_gcc))
# Out:
# Name: Full collaboration Graph
# Type: Graph
# Number of nodes: 7857
# Number of edges: 35783
# Average degree:   9.1086

# %%
# Display the GCC of the informatics network

# %%
# removing external individuals:
# Consider the GCC of the network below as the Informatics Network

# %%
# GCC:

# %%
print(nx.info(main_gcc))
# Out:
# Name:
# Type: Graph
# Number of nodes: 184
# Number of edges: 471
# Average degree:   5.1196

# %% [markdown]
# # 6 year model?
# Are the data representative?
# - Some publications may not be put in Research Explorer?
# - Incomplete information ?
#
# $\Rightarrow$ Constrain the collaboration and topic network to publications from the last size years: ***2012-2017***

# %% [markdown]
# - Total Publications: 3574
# - Collaborators (from informatics): 180

# %%
# Infnet (6yr)

# %%
print(nx.info(g_poinf_only_6yr))
# Out:
# Name:
# Type: Graph
# Number of nodes: 180
# Number of edges: 355
# Average degree:   3.9444

# %%
#GCC

# %%
# Out:
# number of nodes in largest connected component: 170
# Name:
# Type: Graph
# Number of nodes: 170
# Number of edges: 350
# Average degree:   4.1176

# %% [markdown]
# # Community Detection

# %%
import community
# Community detection using modularity maximisation
parts = community.best_partition(main_gcc)
values = [parts.get(node) for node in main_gcc.nodes()]

# %% [markdown]
# ## Pipeline
# <img src='./pipeline.svg'>

# %% [markdown]
# # Topic Modelling

# %%
# Length of summary

# %%
from gensim import models
from gensim.corpora import Dictionary
# ref: http://nbviewer.jupyter.org/github/bmabey/pyLDAvis/blob/master/notebooks/Gensim%20Newsgroup.ipynb
import pyLDAvis.gensim as gensimvis
import pyLDAvis
import cPickle as pkl

# %%
lda_6yr = models.LdaModel.load('../topicModel/lda_6yr.ldamodel')
dictionary_6yr = Dictionary.load('../topicModel/dictionary_6yr.pkl')
corpus_6yr = pkl.load(open('../topicModel/corpus_6yr.pkl', 'rb'))

# %%
vis_data_6yr = gensimvis.prepare(lda_6yr, corpus_6yr, dictionary_6yr)
# Out:
# /Users/weiting/miniconda3/envs/py27/lib/python2.7/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]

# %%
pyLDAvis.display(vis_data_6yr)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el333351119988173607354130718"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# ## Timeline
# <img src='./timeline.svg'>
